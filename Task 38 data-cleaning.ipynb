# %% [markdown]
# #### Basic Cleaning
# #### 1. Load the CSV file using Pandas and display the first 10 rows.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\\Users\\Soham\\Downloads\\messy_customer_loan_dataset - messy_customer_loan_dataset.csv")
df
# Out:
#      Customer ID Age Annual Income credit Score Employment-Type  \
# 0     CUST101160  37        297809          698   Self-Employed
# 1     CUST100077  36       1048283          874        Contract
# 2     CUST100317  55       1043481          661   Self-Employed
# 3     CUST101041  54        369591          722        Salaried
# 4     CUST101358  27        666989          727   Self-Employed
# ...          ...  ..           ...          ...             ...
# 1530  CUST101131  40        477723          719   Self-Employed
# 1531  CUST101295  65       1394481            0   Self-Employed
# 1532  CUST100861  66           NaN          686        Contract
# 1533  CUST101460  45        543340          720        Business
# 1534  CUST101127  61           NaN          731        Salaried
#
#      Education  Level marital_status       city customer_segment  loan_type  \
# 0                12th        Married     Mumbai             Mass  Education
# 1            Graduate         Single     Jaipur          PREMIUM       Auto
# 2        Postgraduate        Married    Kolkata         Affluent       Auto
# 3            Graduate         Single    Kolkata          Premium       Home
# 4            Graduate        Married  Hyderabad             Mass  Education
# ...               ...            ...        ...              ...        ...
# 1530         Graduate         Single     Jaipur             mass  Home Loan
# 1531             12th         Single     Jaipur             Mass   Personal
# 1532            Other        Married      Delhi             Mass   Personal
# 1533         Graduate        Married       Pune             Mass  Education
# 1534     Postgraduate         Single    Chennai         Affluent  Education
#
#      Loan Amount (INR)  tenure Months Monthly Visits debt_to_income  \
# 0               378342             60              3          0.258
# 1               751792             48             11          0.558
# 2               892792             84              4            NaN
# 3               908250             84             10          0.356
# 4               386370             72              4          0.169
# ...                ...            ...            ...            ...
# 1530           1106455             48            NaN          0.569
# 1531            222828            120              8          0.344
# 1532          50000000             36              9          0.084
# 1533            302389             72              9          0.089
# 1534            753995             12              5          0.259
#
#      Loan Approved?
# 0                No
# 1               Yes
# 2               Yes
# 3               Yes
# 4               Yes
# ...             ...
# 1530             No
# 1531            Yes
# 1532            Yes
# 1533             No
# 1534             No
#
# [1535 rows x 15 columns]

# %% [markdown]
# #### 2. Display the number of rows and columns in the dataset.

# %%
df.shape
# Out:
# (1535, 15)

# %% [markdown]
# #### 3. Display all column names and identify which column names have leading/trailing spaces.

# %%
print(df.columns.tolist())

for col in df.columns:
    if col != col.strip():
        print(repr(col))

for col in df.columns:
    print(col)
# Out:
# ['Customer ID', 'Age', 'Annual Income', 'credit Score', 'Employment-Type', 'Education  Level', 'marital_status', 'city', 'customer_segment', 'loan_type', 'Loan Amount (INR)', 'tenure Months', 'Monthly Visits', 'debt_to_income', 'Loan Approved?']
# Customer ID
# Age
# Annual Income
# credit Score
# Employment-Type
# Education  Level
# marital_status
# city
# customer_segment
# loan_type
# Loan Amount (INR)
# tenure Months
# Monthly Visits
# debt_to_income
# Loan Approved?

# %% [markdown]
# #### 4. Clean all column names by removing extra spaces and converting them into a consistent format such as snake_case.

# %%
df.columns = (df.columns.str.strip().str.lower().str.replace(" ", "_"))

print(df.columns.tolist())
# Out:
# ['customer_id', 'age', 'annual_income', 'credit_score', 'employment-type', 'education__level', 'marital_status', 'city', 'customer_segment', 'loan_type', 'loan_amount_(inr)', 'tenure_months', 'monthly_visits', 'debt_to_income', 'loan_approved?']

# %% [markdown]
# #### 5. Check the data type of every column.

# %%
df.dtypes
# Out:
# customer_id          object
# age                  object
# annual_income        object
# credit_score         object
# employment-type      object
# education__level     object
# marital_status       object
# city                 object
# customer_segment     object
# loan_type            object
# loan_amount_(inr)    object
# tenure_months         int64
# monthly_visits       object
# debt_to_income       object
# loan_approved?       object
# dtype: object

# %% [markdown]
# #### 6. Find the total number of missing values in each column.

# %%
df.isnull().sum()
# Out:
# customer_id            0
# age                   71
# annual_income         84
# credit_score          77
# employment-type       60
# education__level      46
# marital_status         0
# city                  52
# customer_segment       0
# loan_type              0
# loan_amount_(inr)    102
# tenure_months          0
# monthly_visits        55
# debt_to_income        89
# loan_approved?         0
# dtype: int64

# %% [markdown]
# #### 7. Find the percentage of missing values in each column.

# %%
df.isnull().sum()/len(df) * 100
# Out:
# customer_id          0.000000
# age                  4.625407
# annual_income        5.472313
# credit_score         5.016287
# employment-type      3.908795
# education__level     2.996743
# marital_status       0.000000
# city                 3.387622
# customer_segment     0.000000
# loan_type            0.000000
# loan_amount_(inr)    6.644951
# tenure_months        0.000000
# monthly_visits       3.583062
# debt_to_income       5.798046
# loan_approved?       0.000000
# dtype: float64

# %% [markdown]
# #### 8. Find all rows where Age is missing.

# %%
df['age'].isnull().sum()
# Out:
# 71

# %% [markdown]
# #### 9. Find all rows where Annual Income is missing.

# %%
df['annual_income'].isnull().sum()
# Out:
# 84

# %% [markdown]
# #### 10.Remove completely duplicate rows and report how many duplicate rows were removed.

# %%
duplicate_count = df.duplicated().sum()

df = df.drop_duplicates()

print(duplicate_count)
# Out:
# 35

# %% [markdown]
# #### Data Type & Invalid Values
# #### 11.The Age column contains numbers as well as values like "unknown" and "twenty five". Clean this column and convert it into a proper numeric column.

# %%
df['age'].replace({'unknown': None,'twenty five': 25})
# Out:
# 0       37
# 1       36
# 2       55
# 3       54
# 4       27
#         ..
# 1530    40
# 1531    65
# 1532    66
# 1533    45
# 1534    61
# Name: age, Length: 1500, dtype: object

# %%
pd.to_numeric(df['age'], errors='coerce')
# Out:
# 0       37.0
# 1       36.0
# 2       55.0
# 3       54.0
# 4       27.0
#         ...
# 1530    40.0
# 1531    65.0
# 1532    66.0
# 1533    45.0
# 1534    61.0
# Name: age, Length: 1500, dtype: float64

# %% [markdown]
# #### 12.The Annual Income column contains values such as 650000 INR, ₹720000, 1.2L, and N/A. Clean the column and convert the valid values into numeric format.

# %%
pd.to_numeric(df['annual_income'], errors='coerce')
# Out:
# 0        297809.0
# 1       1048283.0
# 2       1043481.0
# 3        369591.0
# 4        666989.0
#           ...
# 1530     477723.0
# 1531    1394481.0
# 1532          NaN
# 1533     543340.0
# 1534          NaN
# Name: annual_income, Length: 1500, dtype: float64

# %% [markdown]
# #### 13.Clean the Credit Score column and identify values that cannot be converted into numbers.

# %%
print(pd.to_numeric(df['credit_score'], errors='coerce'))
print(df[df['credit_score'].isna()])
# Out:
# 0       698.0
# 1       874.0
# 2       661.0
# 3       722.0
# 4       727.0
#         ...
# 1530    719.0
# 1531      0.0
# 1532    686.0
# 1533    720.0
# 1534    731.0
# Name: credit_score, Length: 1500, dtype: float64
#      customer_id age  annual_income credit_score employment-type  \
# 23    CUST100382  65       872829.0          NaN   Self-Employed
# 37    CUST100670  27       418793.0          NaN         Unknown
# 47    CUST100598  57       778581.0          NaN             NaN
# 73    CUST100362  62       604483.0          NaN   Self-Employed
# 84    CUST101115  30       858108.0          NaN        Contract
# ...          ...  ..            ...          ...             ...
# 1495  CUST100958  50       774288.0          NaN        Salaried
# 1499  CUST100511  67       499290.0          NaN        Contract
# 1502  CUST100857  32       659245.0          NaN        Business
# 1511  CUST101216  26      1403890.0          NaN             NaN
# 1529  CUST101096  24       520688.0          NaN        Contract
#
#      education__level marital_status     city customer_segment  loan_type  \
# 23       Postgraduate        Married    Delhi             Mass   Personal
# 37           Graduate         Single   Jaipur             Mass   Business
# 47           Graduate        Married  Kolkata          unknown       Home
# 73               12th        Married     Pune         Affluent   Business
# 84               12th        Married   Jaipur             Mass       Auto
# ...               ...            ...      ...              ...        ...
# 1495         Graduate         Single  Kolkata             Mass   Personal
# 1499         Graduate        Married    Delhi          Premium   Business
# 1502              NaN        Married  Kolkata         Affluent  Education
# 1511         Graduate         Single     Pune             Mass       Home
# 1529     Postgraduate       Divorced    Delhi         Affluent       Auto
#
#      loan_amount_(inr)  tenure_months monthly_visits debt_to_income  \
# 23              442006             72              3          0.234
# 37              400096            120              6          0.508
# 47              352976             84              6          0.361
# 73              382571             72            NaN          0.529
# 84              708169             72              5          0.723
# ...                ...            ...            ...            ...
# 1495            697241             72              4          0.323
# 1499            712165            120              7          0.423
# 1502            368435             60              2          0.097
# 1511            328004             72              6           0.05
# 1529            894941             60           five            NaN
#
#      loan_approved?
# 23               No
# 37               No
# 47              Yes
# 73              Yes
# 84               No
# ...             ...
# 1495             No
# 1499            Yes
# 1502              N
# 1511       approved
# 1529            Yes
#
# [76 rows x 15 columns]

# %% [markdown]
# #### 14.The Loan Amount column contains currency symbols, text, and numeric values. Remove the unwanted characters and convert it into numeric format.

# %%
print(df['loan_amount_(inr)'].astype(str).str.replace(r'[^0-9.]', '', regex=True))
print(pd.to_numeric(df['loan_amount_(inr)'], errors='coerce'))
# Out:
# 0         378342
# 1         751792
# 2         892792
# 3         908250
# 4         386370
#           ...
# 1530     1106455
# 1531      222828
# 1532    50000000
# 1533      302389
# 1534      753995
# Name: loan_amount_(inr), Length: 1500, dtype: object
# 0         378342.0
# 1         751792.0
# 2         892792.0
# 3         908250.0
# 4         386370.0
#            ...
# 1530     1106455.0
# 1531      222828.0
# 1532    50000000.0
# 1533      302389.0
# 1534      753995.0
# Name: loan_amount_(inr), Length: 1500, dtype: float64

# %% [markdown]
# #### 15.The Monthly Visits column contains values such as "five", "N/A", and "-". Convert valid values into numeric values and handle invalid values.

# %%
print(df['monthly_visits'].replace({
    'five': 5
}))

print(pd.to_numeric(
    df['monthly_visits'].replace(['N/A', '-'], None),
    errors='coerce'
))
# Out:
# 0        3.0
# 1       11.0
# 2        4.0
# 3       10.0
# 4        4.0
#         ...
# 1530     NaN
# 1531     8.0
# 1532     9.0
# 1533     9.0
# 1534     5.0
# Name: monthly_visits, Length: 1500, dtype: float64
# 0        3.0
# 1       11.0
# 2        4.0
# 3       10.0
# 4        4.0
#         ...
# 1530     NaN
# 1531     8.0
# 1532     9.0
# 1533     9.0
# 1534     5.0
# Name: monthly_visits, Length: 1500, dtype: float64

# %% [markdown]
# #### 16.Clean the Debt to Income column where some values are written like 35% and 0.4x. Convert the valid values into a consistent numeric format.

# %%
print(
    df['debt_to_income']
    .astype(str)
    .str.replace('%', '', regex=False)
    .str.replace('x', '', regex=False)
)

print(pd.to_numeric(
    df['debt_to_income'],
    errors='coerce'
))
# Out:
# 0       0.258
# 1       0.558
# 2         nan
# 3       0.356
# 4       0.169
#         ...
# 1530    0.569
# 1531    0.344
# 1532    0.084
# 1533    0.089
# 1534    0.259
# Name: debt_to_income, Length: 1500, dtype: object
# 0       0.258
# 1       0.558
# 2         NaN
# 3       0.356
# 4       0.169
#         ...
# 1530    0.569
# 1531    0.344
# 1532    0.084
# 1533    0.089
# 1534    0.259
# Name: debt_to_income, Length: 1500, dtype: float64

# %% [markdown]
# #### 17.After cleaning the numerical columns, check which columns are still stored as object data type.

# %%
(df.select_dtypes(include='object').columns)
# Out:
# Index(['customer_id', 'age', 'credit_score', 'employment-type',
#        'education__level', 'marital_status', 'city', 'customer_segment',
#        'loan_type', 'loan_amount_(inr)', 'debt_to_income', 'loan_approved?'],
#       dtype='object')

# %% [markdown]
# #### Categorical Cleaning
# #### 18.Find all unique values in the Employment-Type column.

# %%
df['employment-type'].unique()
# Out:
# array(['Self-Employed', 'Contract', 'Salaried', 'SALARIED',
#        'Self employed', 'Business', nan, 'Unknown', 'self-employed',
#        'salaried'], dtype=object)

# %% [markdown]
# #### 19.Standardize the Employment-Type column so that values such as salaried, SALARIED, and Salaried become one consistent value.

# %%
print(df['employment-type'].str.lower())

print(df['employment-type'].unique())
# Out:
# 0       self-employed
# 1            contract
# 2       self-employed
# 3            salaried
# 4       self-employed
#             ...
# 1530    self-employed
# 1531    self-employed
# 1532         contract
# 1533         business
# 1534         salaried
# Name: employment-type, Length: 1500, dtype: object
# ['self-employed' 'contract' 'salaried' 'self employed' 'business' nan
#  'unknown']

# %% [markdown]
# #### 20.Clean the Education Level column and make values such as graduate, GRADUATE, and Graduate consistent.

# %%
print (df['education__level'].str.lower().str.strip())

print(df['education__level'].unique())
# Out:
# 0               12th
# 1           graduate
# 2       postgraduate
# 3           graduate
# 4           graduate
#             ...
# 1530        graduate
# 1531            12th
# 1532           other
# 1533        graduate
# 1534    postgraduate
# Name: education__level, Length: 1500, dtype: object
# ['12th' 'Graduate' 'Postgraduate' 'Diploma' nan 'Post Graduate' 'Other'
#  'GRADUATE' 'postgraduate' 'graduate']

# %% [markdown]
# #### 21.Clean the City column. Identify incorrect or inconsistent values such as hyderbad, Hyd, Bangalore, and Bengaluru.

# %%
print(df['city'].str.lower().str.strip())

print(df['city'].replace({
    'hyderbad': 'hyderabad',
    'hyd': 'hyderabad',
    'bengaluru': 'bangalore'
}))

print(df['city'].unique())
# Out:
# 0          mumbai
# 1          jaipur
# 2         kolkata
# 3         kolkata
# 4       hyderabad
#           ...
# 1530       jaipur
# 1531       jaipur
# 1532        delhi
# 1533         pune
# 1534      chennai
# Name: city, Length: 1500, dtype: object
# 0          Mumbai
# 1          Jaipur
# 2         Kolkata
# 3         Kolkata
# 4       Hyderabad
#           ...
# 1530       Jaipur
# 1531       Jaipur
# 1532        Delhi
# 1533         Pune
# 1534      Chennai
# Name: city, Length: 1500, dtype: object
# ['Mumbai' 'Jaipur' 'Kolkata' 'Hyderabad' 'Chennai' 'Bengaluru' nan 'Delhi'
#  'Pune' 'MUMBAI' 'Hyd' 'mumbai' 'Bangalore' 'hyderbad']

# %% [markdown]
# #### 22.Find all unique values in the Customer Segment column and identify invalid categories.

# %% [markdown]
# #### 23.Clean the Loan Type column so that values such as personal, PERSONAL, and personal loan are standardized.

# %% [markdown]
# #### 24.Clean the Loan Approved column where values include Yes, yes, Y, 1, No, NO, N, and 0. Convert them into only Yes/No.
