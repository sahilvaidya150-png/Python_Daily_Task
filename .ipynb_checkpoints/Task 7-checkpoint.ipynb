# %% [markdown]
# ### Q1. Create a set with numbers {1, 2, 3, 2, 4, 1} and print it. What do you observe?

# %%
numbers={1, 2, 3, 2, 4, 1}

print(numbers)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ### Q2. Create an empty set using correct syntax and add 3 numbers using add().

# %%
empty=set()

empty.add(1)
empty.add(2)
empty.add(3)
print(empty)
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Q3. Given s = {10, 20, 30}, add multiple elements [40, 50, 60] using update().

# %%
s = {10, 20, 30}

s.update( [40, 50, 60])
print(s)
# Out:
# {40, 10, 50, 20, 60, 30}

# %% [markdown]
# ### Q4. Remove element 20 from set s = {10, 20, 30, 40} using remove() and discard(). Show difference.

# %%
s = {10, 20, 30, 40}

s.remove(20)
print("remove:",s)
s.discard(20)
print("discard:",s)
# Out:
# remove: {40, 10, 30}
# discard: {40, 10, 30}

# %% [markdown]
# ### Q5. Create two sets A = {1, 2, 3, 4} and B = {3, 4, 5, 6}. Print union, intersection, and difference.

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ### Q6. Check if 25 is present in set s = {10, 20, 30, 40} using in keyword.

# %%
s = {10, 20, 30, 40}

if 25 in s:
    print("yes")

# %% [markdown]
# ### Q7. Create a set from the list [1, 2, 2, 3, 4, 4, 5] and print its length.

# %%
list1 = [1, 2, 2, 3, 4, 4, 5]
sets=set(list1)

print(sets)
print("Length",len(sets))
# Out:
# {1, 2, 3, 4, 5}
# Length 5

# %% [markdown]
# ### Q8. Take 5 numbers as input from user, store them in a set, and print unique numbers only.

# %%
sets=set()

for i in range(5):
    num=int(input("enter a number:"))
    sets.add(num)
print(sets)
# Out:
# enter a number: 5
# enter a number: 5
# enter a number: 4
# enter a number: 6
# enter a number: 8
# {8, 4, 5, 6}

# %% [markdown]
# ### Q9. Given two sets A = {1, 2, 3} and B = {3, 4, 5}, print elements that are in A but not in B.

# %%
A = {1, 2, 3} 
B = {3, 4, 5}

print(A.difference(B))
# Out:
# {1, 2}

# %% [markdown]
# ### Q10. Create a set and try to add a list [1,2,3] inside it. What happens?

# %%
Sets={}

Sets.add([1,2,3])
print(sets)
# Out:
# ------------------------------------------------------------------------
# AttributeError                         Traceback (most recent call last)
# Cell In[176], line 3
#       1 Sets={}
# ----> 3 Sets.add([1,2,3])
#       4 print(sets)
#
# AttributeError: 'dict' object has no attribute 'add'

# %% [markdown]
# ### Q11. Take age as input. If age >= 18, print "You are eligible to vote".

# %%
age = int(input("enter a age:"))

if age >= 18:
    print("You are eligible to vot")
# Out:
# enter a age: 19
# You are eligible to vot

# %% [markdown]
# ### Q12. Take a number and check if it is positive, negative, or zero using if-elif- else.

# %%
num= int(input("enetr a number:"))

if num > 0:
    print("positve")

elif num < 0:
    print("negative")

else:
    print("zero")
# Out:
# enetr a number: -1
# negative

# %% [markdown]
# ### Q13. Take two numbers and print the larger one using if-else.

# %%
num1=int(input("enter a number 1:"))
num2=int(input("enter a number 2:"))

if num1 > num2:
    print("larger number :",num1)

else :
    print("larger number:",num2)
# Out:
# enter a number 1: 48
# enter a number 2: 75
# larger number: 75

# %% [markdown]
# ### Q14. Take a character and check if it is a vowel (a, e, i, o, u) using if statement.

# %%
char=input("enter a character:")

vowel= "a,e,i,o,u"

if char in "aeiou":
    print("it is a vowel")

else:
    
    print("it is not vowel")
# Out:
# enter a character: a
# it is a vowel

# %% [markdown]
# ### Q15. Take marks and print grade: ≥90 → A, ≥80 → B, ≥70 → C, else → Fail.

# %%
marks=int(input("enter a marks:"))

if marks >=90:
    print("grade A")

elif marks >=80:
    print("grade B")

elif marks >=70:
    print("grade C")

else:
    print("fail")
# Out:
# enter a marks: 84
# grade B

# %% [markdown]
# ### Q16. Take three numbers and print the largest one using if-elif-else.

# %%
num1 =int(input("enter a number 1:"))
num2 =int(input("enter a number 2:"))
num3 =int(input("enter a number 3:"))

if num1 >= num2 and num1 >= num3:
    print("largest number 1")

elif num2 >= num3 and num3 >= num1:
    print("largest number 2")

elif num3 >= num1 and num3 >= num2:
    print("largest number 3")
# Out:
# enter a number 1: 85
# enter a number 2: 78
# enter a number 3: 42
# largest number 1

# %% [markdown]
# ### Q17. Take a number and check if it is even and greater than 50.

# %%
num=int(input("enter a number:"))

if num % 2 == 0 and  num >= 50:
    print("even number")

else:
    print("NOT enevn and NOT greater")
# Out:
# enter a number: 78
# even number

# %% [markdown]
# ### Q18. Take username and password. If username == "admin" and password == "1234", print "Login Successful", else "Login Failed".

# %%
username = input("Enter a user name:") 
password = input("Enter a password:")

if username == "admin" and password == "1234":
    print("Login Successful")

else :
    print("Login Failed")
# Out:
# Enter a user name: admin
# Enter a password: 1234
# Login Successful

# %% [markdown]
# ## Q19. Take a year as input and check if it is a leap year (divisible by 4 but not 100, or divisible by 400).

# %%
year= int(input("Enetr a year"))

if year % 4 == 0 and year % 100 != 0 or year % 400 == 0:
    print("It is a leap year")

else :
    print("It is not leap year")
# Out:
# Enetr a year 2024
# It is a leap year

# %% [markdown]
# ### Q20. Take three sides of a triangle and check if they can form a valid triangle (sum of any two sides > third side

# %%
side_1=int(input("enter a side 1:"))
side_2=int(input("enter a side 2:"))
side_3=int(input("enter a side 3:"))


if side_1 + side_2 > side_3 and side_2 + side_3 > side_1 and side_3 + side_1 > side_2:
    print("valid triangle")

else :
    print("not valide triangle")
# Out:
# enter a side 1: 3
# enter a side 2: 4
# enter a side 3: 5
# valid triangle

# %% [markdown]
# ### Q1. (Hard) Take three numbers as input from the user. Print the largest number and also check whether all three numbers are equal or not.

# %%
num1 =int(input("enter a number 1:"))
num2 =int(input("enter a number 2:"))
num3 =int(input("enter a number 3:"))


if num1 >= num2 and num1 >= num3  :
    print("largest number 1")

elif num2 >= num1 and num2 >= num3:
    print("largest number 2")

else:
    print("largest number 3")

if num1==num2==num3:
    print("all three numberare equal")

else:
    print("all three number re not equal")
# Out:
# enter a number 1: 10
# enter a number 2: 10
# enter a number 3: 10
# largest number 1
# all three numberare equal

# %% [markdown]
# ### Q2. (Hard) Take a year as input. Check if it is a leap year or not. (A year is leap if divisible by 4, but not by 100, unless also divisible by 400)

# %%
year= int(input("Enetr a year"))

if year % 4 == 0 and year % 100 != 0 or year % 400 == 0:
    print("It is a leap year")

else :
    print("It is not leap year")
# Out:
# Enetr a year 2003
# It is not leap year

# %% [markdown]
# ### Q3. (Hard) Take three sides of a triangle as input. Check if they can form a valid triangle (sum of any two sides must be greater than the third side). If valid, also print the type (Equilateral, Isosceles, or Scalene).

# %%
side_1=int(input("enter a side 1:"))
side_2=int(input("enter a side 2:"))
side_3=int(input("enter a side 3:"))


if (side_1 + side_2 >= side_3) and (side_1 + side_3 >= side_2) and (side_2 + side_3 >= side_1):
    print("valid triangle")
    if (side_1 == side_2) and (side_2 == side_3):
        print("Equilateral")
    elif (side_1 == side_2) or (side_2 == side_3) or (side_1 == side_3):
        print("Isosceles")
    else:
        print("Scalene")

else :
    print("invalide triangle")
# Out:
# enter a side 1: 45
# enter a side 2: 45
# enter a side 3: 90
# valid triangle
# Isosceles

# %% [markdown]
# ### Q4. (Hard) Take a student's marks in 5 subjects. Calculate percentage and print grade
# ### according to these rules:
# ### • 90 or above → A+
# ### • 80–89 → A
# ### • 70–79 → B
# ### • 60–69 → C
# ### • Below 60 → Fail Also print "Passed with Distinction" if percentage >= 75.

# %%
s1=int(input("enter a marks 1:"))
s2=int(input("enter a marks 2:"))
s3=int(input("enter a marks 3:"))
s4=int(input("enter a marks 4:"))
s5=int(input("enter a marks5:"))

total = s1+s2+s3+s4+s5
print("Total Marks:",total)
percentage = total /5
print("Total Percentage:",percentage)

if percentage >= 90:
    print("grade A+:",percentage)

elif percentage >= 80:
    print("grade A:",percentage)

elif percentage >= 70:
    print("grade B:",percentage)

elif percentage >= 60:
    print("grade C:",percentage)

else:
    print("fail")
# Out:
# enter a marks 1: 98
# enter a marks 2: 97
# enter a marks 3: 96
# enter a marks 4: 95
# enter a marks5: 94
# Total Marks: 480
# Total Percentage: 96.0
# grade A+: 96.0

# %% [markdown]
# ### Q5. (Hard) Take username, password, and age as input.
# ### • If username == "admin" and password == "python123" and age >= 18 → Print
# ### "Login Successful"
# ### • Else if age < 18 → Print "You are too young to login"
# ### Else → Print "Invalid Credentials"

# %%
username = input("Enter a user name") 
password = input("Enter a password")
age=int(input("Enter a age"))

if username == "admin" and password == "python123" and age >= 18:
    print("Login Successful")

else :
    if age < 18:
        print("You are too young to login")

    else:
        print("Invalid Credentials")
# Out:
# Enter a user name admin
# Enter a password python123
# Enter a age 23
# Login Successful
