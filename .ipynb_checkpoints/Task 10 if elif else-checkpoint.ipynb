# %% [markdown]
# ### 1. Take a number as input. If the number is positive, check whether it is even or odd and print the result.

# %%
num= int(input("Enter the Number:"))

if num >= 0 :
    if num % 2 == 0:
        print("Even Nuber")
    else:
        print("Odd Number")

else:
    print("Not positive number")
# Out:
# Enter the Number: -45
# Not positive number

# %% [markdown]
# ### 2. Take age as input. If age is greater than or equal to 18, check if the person is a senior citizen (age >= 60) or adult.

# %%
age = int(input("Enter the age:"))

if age >= 18 :
    if age >= 60:
        print("Senior Citizen")

    else:
        print("adilt")

else:
    print("child")
# Out:
# Enter the age: 12
# child

# %% [markdown]
# ### 3. Take a single character. If it is an alphabet, check whether it is uppercase or lowercase.

# %%
char=input("Enter the character:")

if char.isalpha():
    if char.isupper():
        print("Upper case")
    else:
        print("lower case")

else:
    print("it is a not alphabet")
# Out:
# Enter thecharacter: SAHIL
# Upper case

# %% [markdown]
# ### 4. Take three numbers as input and print the largest number using nested if statements (without using max()).

# %%
a= int(input("Enter the Number a:"))
b= int(input("Enter the Number b:"))
c= int(input("Enter the Number c:"))

if a > b:
    if a > c:
        print("the largest number a")

    else:
        print("the largest number c")

else:
    if b > c:
        print("the largest number b")

    else:
        print("the largest number c")
# Out:
# Enter the Number a: 12
# Enter the Number b: 45
# Enter the Number c: 78
# the largest number c

# %% [markdown]
# ### 5. Take student marks. If marks >= 40 (Pass), then further check if marks >= 75 to print "Pass with Distinction".

# %%
marks= int(input("Enter the marks:"))

if marks >= 40 :
    if marks >=75:
        print("pass with distinction")

    else:
        print("Pass")

else:
    print("Fail")
# Out:
# Enter the marks: 98
# pass with distinction

# %% [markdown]
# ### 6. Take a number. If it is divisible by 2, check if it is also divisible by 4.

# %%
num= int(input("Enter the Number:"))

if num % 2 == 0:
    if num % 4 == 0:
        print("Divisible by 4 and 2")

    else:
        print("The number is divisible by 2 but not by 4")

else:
    print("Not Divisible by 2 ")
# Out:
# Enter the Number: 22
# The number is divisible by 2 but not by 4

# %% [markdown]
# ### 7. Take username and password. If username is "admin", then check if the password is correct.

# %%
username="admin"
password=1234

user=input("Enter the user name:")
user_password=int(input("Enter the Password:"))

if username == user:
    if user_password == password:
        print("Login successfully")

    else:
        print("incorrect password")

else:
    print("incorrect user name")
# Out:
# Enter the user name: admin
# Enter the Password: 1234
# Login successfully

# %% [markdown]
# ### 8. Take three sides of a triangle. First check if they form a valid triangle, then check if it is Equilateral, Isosceles, or Scalene.

# %%
a= int(input("Enter the Number side 1:"))
b= int(input("Enter the Number side 2:"))
c= int(input("Enter the Number side 3:"))

if a + b >= c and a + c >= b and c + b >= a:
    if a == b and b == c:
        print("Equilateral ")

    elif a== b or b == c or c == a:
        print("Isoscele")

    else:
         print("scalene")

else :
   print("Not valid triangle")
# Out:
# Enter the Number side 1: 45
# Enter the Number side 2: 90
# Enter the Number side 3: 45
# Isoscele

# %% [markdown]
# ### 9. Take salary and years of experience. If salary > 50000, check experience to decide "Manager" or "Senior Manager".

# %%
salary= int(input("Enter the salary:"))

if salary >= 50000:
    experience= int(input("Enetr the experience:"))
    if experience >= 10:
        print("Senior manager")

    else:
        print("Manager")

else:
    print("Salary must be greater than 50000")
# Out:
# Enter the salary: 50000
# Enetr the experience: 5
# Manager

# %% [markdown]
# ### 10.Take a character. If it is a letter, check if it is vowel or consonant. If it is a digit, print "Digit". Else print "Special Character".

# %%
char=input("Enter the character:")


if char.isalpha():
        if char.lower() in "aeiou" :
            print("vowel")
        else:
            print("consonant")

elif char.isdigit():
    print("Digit")
else:
    print("Specail character")
# Out:
# Enter the character: a
# vowel

# %% [markdown]
# ### 11.Take a year as input. Check if it is a leap year using nested conditions.

# %%
 year=int(input("Enter the year:"))

if year % 4 == 0:
    if year % 100 == 0 and year % 400 == 0:
        print("Leap year")

    else:
        print("not leap year")

else:
    print("not leap year")
# Out:
# Enter the year: 2004
# not leap year

# %%
year = int(input("Enter a year: "))

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("Leap Year")
        else:
            print("Not a Leap Year")
    else:
        print("Leap Year")
else:
    print("Not a Leap Year")

# %% [markdown]
# ### 12.Take temperature. If temperature > 30 print "Hot", if between 20-30 print "Warm", else "Cold" using nested if.

# %%
temp= int(input("Enter a temperature:"))

if temp > 30:
    print("Hot")
else:
    if temp >= 20:
        if temp <= 30:
            print("Warm")
    else:
        print("Cold")
# Out:
# Enter a temperature: 12
# Cold

# %% [markdown]
# ##### 13.Take three numbers. Check if all three are equal, or any two are equal using nested if.

# %%
a= int(input("Enter the Number a:"))
b= int(input("Enter the Number b:"))
c= int(input("Enter the Number c:"))

if a == b:
    if b == c :
        print("three are equal")

    else:
        print("Any Two Are Equal a and b ")

else:
    if a == c:
        print("Two Equal a and c")

    else :
        if b == c:
            print("Two Equal b and c")

        else:
            print(" a, b and c different")
# Out:
# Enter the Number a: 45
# Enter the Number b: 45
# Enter the Number c: 45
# three are equal

# %% [markdown]
# ### 14.Take a number. If it is positive and even, print "Positive Even Number".

# %%
num= int(input("Enter the Number:"))

if num >= 0 :
    if num % 2 == 0:
        print("Positive Even Number")

    else:
        print("Positive odd Number")

else:
    print("Not positive Even number")
# Out:
# Enter the Number: -12
# Not positive Even number

# %% [markdown]
# ### 15.Take marks of 5 subjects. If average >= 60, then check if all subjects are above 40 marks.

# %%
s1=int(input("enter a marks 1:"))
s2=int(input("enter a marks 2:"))
s3=int(input("enter a marks 3:"))
s4=int(input("enter a marks 4:"))
s5=int(input("enter a marks5:"))


average = (s1 + s2 + s3 + s4 + s5) / 5

if average >= 60:
    if s1 > 40 and s2 > 40 and s3 > 40 and s4 > 40 and s5 > 40:
        print("Average is 60 or above and all subjects are above 40 marks")
    else:
        print("Average is 60 or above, but all subjects are not above 40 marks")
else:
    print("Average is below 60")
# Out:
# enter a marks 2: 78
# enter a marks 3: 98
# enter a marks 4: 96
# enter a marks5: 57
# Average is 60 or above and all subjects are above 40 marks

# %% [markdown]
# ### 16.Take username, password, and age. If username and password are correct and age >= 18, print "Login Successful". Else if age < 18, print age restriction message.

# %%
username=input("Enter the user name:")
password=input("Enter the password:")
age= int(input("Enter the age:"))

if username == "sahil" and password == "9922":
    if age >= 18:
        print("Login Successful")

    else:
        print("age restriction")

else:
    print("Invalid Username or Password")
# Out:
# Enter the user name: sahil
# Enter the password: 9922
# Enter the age: 23
# Login Successful

# %% [markdown]
# ### 17.Take a number. Check if it is divisible by both 3 and 5 using nested if.

# %%
num= int(input("Enter the Number:"))

if num % 3 == 0:
    if num % 5 == 0:
        print("Divisible by 3 and 5")

    else:
        print("The number is divisible by 3 but not by 5")

else:
    print("Not Divisible by 5 but not by 3")
# Out:
# Enter the Number: 15
# Divisible by 3 and 5

# %% [markdown]
# ### 18.Take three sides of a triangle. Check if valid, then check if it is a right-angled triangle using Pythagoras theorem.

# %%
a= int(input("Enter the Number side 1:"))
b= int(input("Enter the Number side 2:"))
c= int(input("Enter the Number side 3:"))

if a + b >= c and a + c >= b and c + b >= a:
    print("valid triangle")
    if a**2 + b**2 >= c**2 and a**2 + c**2 >= b**2 and c**2 + b**2 >= a**2:
        print("right angled triange")

    else:
        print("Not a right angled triangle")

else:
    print("invalid triangle")
# Out:
# Enter the Number side 1: 74
# Enter the Number side 2: 45
# Enter the Number side 3: 78
# valid triangle
# right andled triange

# %% [markdown]
# ### 19.Take a grade (A, B, C, D, F) and print full description using if-elif-else (Excellent, Good, Average, etc.).

# %%
grade=input("Enter a grade (A, B, C, D, F):")

if grade == "A":
    print("EXcellent")

elif grade == "B":
    print("Good")

elif grade == "C":
    print("Average")

elif grade == "D":
    print("poor")

else:
    print("fail")
# Out:
# Enter a grade (A, B, C, D, F): f
# fail

# %% [markdown]
# ### 20.Take income. If income > 1000000, check tax slab. If income between 500000- 1000000, different slab. Else print "Low Income".

# %%
income= int(input("Enter the income"))

if income >= 500000:
    if income >= 1000000 :
        print("check tax slab")
    else:
        print("different slab")

else:
    print("low income")
# Out:
# Enter the income 1100000
# check tax slab

# %% [markdown]
# ### # Extra More Question (Optional)
# ### 1. (Hard) Take three sides of a triangle as input. First check if they can form a valid triangle (sum of any two sides > third side). If valid, then further check and print whether the triangle is Equilateral, Isosceles, or Scalene.

# %%
a= int(input("Enter the Number side 1:"))
b= int(input("Enter the Number side 2:"))
c= int(input("Enter the Number side 3:"))

if a + b >= c and a + c >= b and c + b >= a:
    print("valid triangle")
    if a == b and b == c:
        print("Equilateral ")

    elif a== b or b == c or c == a:
        print("Isoscele")

    else:
         print("scalene")

else :
   print("Not valid triangle")
# Out:
# Enter the Number side 1: 45
# Enter the Number side 2: 45
# Enter the Number side 3: 90
# valid triangle
# Isoscele

# %% [markdown]
# ### 2. (Hard) Take a student's marks in 5 subjects. Calculate the average. If average >= 60, then check if all individual subjects are above 40. If yes, print "Pass with Good Performance", else print "Pass but Weak in some subjects". If average < 60, print "Fail".

# %%
s1=int(input("enter a marks 1:"))
s2=int(input("enter a marks 2:"))
s3=int(input("enter a marks 3:"))
s4=int(input("enter a marks 4:"))
s5=int(input("enter a marks5:"))


average = (s1 + s2 + s3 + s4 + s5) / 5

if average >= 60:
    if s1 > 40 and s2 > 40 and s3 > 40 and s4 > 40 and s5 > 40:
        print("Pass with Good Performance")
    else:
        print("Pass but Weak in some subjects")
else:
    print("Fail")
# Out:
# enter a marks 1: 78
# enter a marks 2: 87
# enter a marks 3: 94
# enter a marks 4: 95
# enter a marks5: 65
# Pass with Good Performance

# %% [markdown]
# ### 3. (Hard) Take username, password, and age as input.
# ### • If username == "admin" and password == "python123" and age >= 18, print
# ### "Login Successful".
# ### • Else if age < 18, print "You are too young to login".
# ### • Else if username is wrong, print "Invalid Username".
# ### • Else print "Invalid Password".

# %%
username=input("Enter the user name:")
password=input("Enter the password:")
age= int(input("Enter the age:"))

if age >= 18 :
    if username == "admin":
        if password == "pytho123":
            print("Login Successful")

        else:
            print("Invalid  Password")
        
    else:
        print("Invalid Username")

else:
    print("You are too young to login")
# Out:
# Enter the user name: admin
# Enter the password: python
# Enter the age: 14
# You are too young to login

# %% [markdown]
# ### 4. (Hard) Take a number as input. Check if the number is positive. If positive, check if it is divisible by both 3 and 5. If yes, print "FizzBuzz". If only divisible by 3 print "Fizz", only by 5 print "Buzz". If negative, print "Negative Number".

# %%
num=int(input("Enter the number:"))

if num > 0 :
    if num % 3 ==0 and num % 5== 0:
        print("FizzBuzz")

    else:
        if num % 3==0:
            print("Fizz")
        else:
            if num % 5== 0:
                print("Buzz")
            else:
                print("the number not divisible by 3 and 5") 

else:
    print("Negative Number")
# Out:
# Enter the number: 15
# FizzBuzz

# %% [markdown]
# ### 5. (Hard) Take three numbers. First check if all three are equal. If not, check which one is the largest. Also check if the largest number is even or odd and print all information accordingly.

# %%
a= int(input("Enter the Number a:"))
b= int(input("Enter the Number b:"))
c= int(input("Enter the Number c:"))

if a == b == c :
    print("All three are equal")
    
else :
    if a > b and a > c:
        largest = a
        print("largest number a:",a)
    elif b > c and b > a:
        largest = b
        print("largest number b:",b)

    else:
        largest = c
        print("largest number c:",c)

    if largest % 2 == 0:
        print("largest number even:",largest)

    else :
        print("largest number odd:",largest)
# Out:
# Enter the Number a: 78
# Enter the Number b: 45
# Enter the Number c: 12
# largest number a: 78
# largest number even: 78
