# %%
# Method Overloading Questions (1-7)
# 1. Create a Calculator class that can add 2 numbers or 3 numbers using the same method
# name.
# Concept
# Method Overloading (Python uses default arguments or *args to achieve overloading.)
# What to do
# • Create a class Calculator.
# • Create one method add().
# • The method should work for either 2 numbers or 3 numbers.
# How to solve
# 1. Create class Calculator.
# 2. Define method add().
# 3. Use default arguments or *args.
# 4. Check how many numbers are provided.
# 5. Return the sum.

class Calculator:

    def add(self, a, b, c=0):
        return a + b + c

# Object
obj = Calculator()

print("Sum of 2 numbers:", obj.add(10, 20))
print("Sum of 3 numbers:", obj.add(10, 20, 30))
# Out:
# Sum of 2 numbers: 30
# Sum of 3 numbers: 60

# %%
# 2. Create an Area class that calculates the area of a square and rectangle using the same
# method.
# Concept
# Method Overloading using default arguments.
# What to do
# • One parameter → Square.
# • Two parameters → Rectangle.
# How to solve
# 1. Create class Area.
# 2. Define method calculate().
# 3. If only one value is provided, calculate the square's area.
# 4. If two values are provided, calculate the rectangle's area.
# 5. Return the result.

class Area:

    def calculate(self, length, width=None):
        if width is None:
            return length * length
        else:
            return length * width

# Object
obj = Area()

print("Area of Square:", obj.calculate(5))
print("Area of Rectangle:", obj.calculate(5, 8))
# Out:
# Area of Square: 25
# Area of Rectangle: 40

# %%
# 3. Create a Student class with a details() method that accepts different numbers of
# arguments.
# Concept
# Method Overloading
# What to do
# The method should work with:
# • Name
# • Name + Age
# • Name + Age + City
# How to solve
# 1. Create class Student.
# 2. Create method details().
# 3. Use default arguments.
# 4. Print the information based on the provided values.

class Student:

    def details(self, name, age=None, city=None):
        if age is None and city is None:
            print("Name:", name)

        elif city is None:
            print("Name:", name)
            print("Age:", age)

        else:
            print("Name:", name)
            print("Age:", age)
            print("City:", city)

# Object
obj = Student()

obj.details("Sahil")
print()

obj.details("Sahil", 21)
print()

obj.details("Sahil", 21, "Hyderabad")
# Out:
# Name: Sahil
#
# Name: Sahil
# Age: 21
#
# Name: Sahil
# Age: 21
# City: Hyderabad

# %%
# 4. Create a MathOperations class that multiplies any number of values.
# Concept
# Method Overloading using *args
# What to do
# Multiply:
# • 2 numbers
# • 3 numbers
# • 4 numbers
# • More numbers
# How to solve
# 1. Create class MathOperations.
# 2. Define method multiply(*args).
# 3. Initialize the answer as 1.
# 4. Loop through all numbers.
# 5. Multiply each number.
# 6. Return the final product.

class MathOperations:

    def multiply(self, *args):
        result = 1

        for i in args:
            result *= i

        return result

# Object
obj = MathOperations()

print("2 Numbers:", obj.multiply(2, 3))
print("3 Numbers:", obj.multiply(2, 3, 4))
print("4 Numbers:", obj.multiply(2, 3, 4, 5))
print("5 Numbers:", obj.multiply(2, 3, 4, 5, 6))
# Out:
# 2 Numbers: 6
# 3 Numbers: 24
# 4 Numbers: 120
# 5 Numbers: 720

# %%
# 5. Create a Display class that prints different messages based on the argument type.
# Concept
# Method Overloading + Type Checking
# What to do
# Accept:
# • Integer
# • String
# • List
# How to solve
# 1. Create class Display.
# 2. Create method show().
# 3. Use isinstance().
# 4. Print different messages depending on the object's type.

class Display:

    def show(self, value):
        if isinstance(value, int):
            print("Integer Value:", value)

        elif isinstance(value, str):
            print("String Value:", value)

        elif isinstance(value, list):
            print("List Value:", value)

        else:
            print("Unknown Data Type")

# Object
obj = Display()

obj.show(100)
obj.show("Python")
obj.show([10, 20, 30])
obj.show(12.5)
# Out:
# Integer Value: 100
# String Value: Python
# List Value: [10, 20, 30]
# Unknown Data Type
