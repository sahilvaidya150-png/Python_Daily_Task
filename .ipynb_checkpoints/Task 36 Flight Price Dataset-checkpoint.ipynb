# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Soham\\Downloads\\Data_Train.xlsx - Sheet1.csv")
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# #### 1. Load the Flight Price dataset into a Pandas DataFrame and display the first five rows.

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# #### 2. Find the number of rows and columns in the dataset.

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# #### 3. Display all column names in the dataset.

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# #### 4. Display the data types of all columns.

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# #### 5. Use df.info() to inspect the structure of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# #### 6. Check the number of missing values in each column.

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# #### 7. Check the percentage of missing values in each column.

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# Airline            0.000000
# Date_of_Journey    0.000000
# Source             0.000000
# Destination        0.000000
# Route              0.009361
# Dep_Time           0.000000
# Arrival_Time       0.000000
# Duration           0.000000
# Total_Stops        0.009361
# Additional_Info    0.000000
# Price              0.000000
# dtype: float64

# %% [markdown]
# #### 8. Display the unique values and frequency of each value in the Airline column.

# %%
df['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %% [markdown]
# #### 9. Display the frequency distribution of Total_Stops, including missing values.

# %%
df['Total_Stops'].describe()
# Out:
# count      10682
# unique         5
# top       1 stop
# freq        5625
# Name: Total_Stops, dtype: object

# %% [markdown]
# #### 10.Convert Date_of_Journey into a datetime format.

# %%
df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey']).dt.month
df['Date_of_Journey']
# Out:
# 0        3
# 1        5
# 2        6
# 3        5
# 4        3
#         ..
# 10678    4
# 10679    4
# 10680    4
# 10681    3
# 10682    5
# Name: Date_of_Journey, Length: 10683, dtype: int32

# %% [markdown]
# #### 11.Extract the day from Date_of_Journey and create a day column.

# %%
pd.to_datetime(df['Date_of_Journey']).dt.day
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4         1
#          ..
# 10678     9
# 10679    27
# 10680    27
# 10681     1
# 10682     9
# Name: Date_of_Journey, Length: 10683, dtype: int32

# %% [markdown]
# #### 12.Extract the month from Date_of_Journey and create a month column.

# %%
pd.to_datetime(df['Date_of_Journey']).dt.month
# Out:
# 0        3
# 1        5
# 2        6
# 3        5
# 4        3
#         ..
# 10678    4
# 10679    4
# 10680    4
# 10681    3
# 10682    5
# Name: Date_of_Journey, Length: 10683, dtype: int32

# %% [markdown]
# #### 13.Extract the year from Date_of_Journey and create a year column.

# %%
pd.to_datetime(df['Date_of_Journey']).dt.year
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 10678    2019
# 10679    2019
# 10680    2019
# 10681    2019
# 10682    2019
# Name: Date_of_Journey, Length: 10683, dtype: int32

# %% [markdown]
# #### 14.Drop the original Date_of_Journey column after extracting the required features.

# %%
df.drop('Date_of_Journey', axis=1)
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price  Month
# 0      01:10 22 Mar   2h 50m    non-stop         No info   3897      3
# 1             13:15   7h 25m     2 stops         No info   7662      5
# 2      04:25 10 Jun      19h     2 stops         No info  13882      6
# 3             23:30   5h 25m      1 stop         No info   6218      5
# 4             21:35   4h 45m      1 stop         No info  13302      3
# ...             ...      ...         ...             ...    ...    ...
# 10678         22:25   2h 30m    non-stop         No info   4107      4
# 10679         23:20   2h 35m    non-stop         No info   4145      4
# 10680         11:20       3h    non-stop         No info   7229      4
# 10681         14:10   2h 40m    non-stop         No info  12648      3
# 10682         19:15   8h 20m     2 stops         No info  11753      5
#
# [10683 rows x 11 columns]

# %% [markdown]
# #### 15.Convert Dep_Time into datetime format and extract the departure hour into Dep_Hour.

# %%
df['Dep_Time']= pd.to_datetime(df['Dep_Time'],format= "%H:%M")
df['Dep_Time']
# Out:
# 0       1900-01-01 22:20:00
# 1       1900-01-01 05:50:00
# 2       1900-01-01 09:25:00
# 3       1900-01-01 18:05:00
# 4       1900-01-01 16:50:00
#                 ...
# 10678   1900-01-01 19:55:00
# 10679   1900-01-01 20:45:00
# 10680   1900-01-01 08:20:00
# 10681   1900-01-01 11:30:00
# 10682   1900-01-01 10:55:00
# Name: Dep_Time, Length: 10683, dtype: datetime64[ns]

# %% [markdown]
# #### 16.Extract the departure minute from Dep_Time and create Dep_Minute.

# %%
pd.to_datetime(df['Dep_Time']).dt.minute
# Out:
# C:\Users\Soham\AppData\Local\Temp\ipykernel_21528\588458865.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df['Dep_Time']).dt.minute
# 0        20
# 1        50
# 2        25
# 3         5
# 4        50
#          ..
# 10678    55
# 10679    45
# 10680    20
# 10681    30
# 10682    55
# Name: Dep_Time, Length: 10683, dtype: int32

# %% [markdown]
# #### 17.Drop the original Dep_Time column after extracting the required features.

# %%
df.drop('Dep_Time',axis=1)
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL         21:35   4h 45m      1 stop
# ...                      ...           ...      ...         ...
# 10678              CCU → BLR         22:25   2h 30m    non-stop
# 10679              CCU → BLR         23:20   2h 35m    non-stop
# 10680              BLR → DEL         11:20       3h    non-stop
# 10681              BLR → DEL         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 10 columns]

# %% [markdown]
# #### 18.Extract only the time portion from Arrival_Time.

# %%
pd.to_datetime(df['Arrival_Time']).dt.time
# Out:
# C:\Users\Soham\AppData\Local\Temp\ipykernel_21528\256876500.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df['Arrival_Time']).dt.time
# 0        01:10:00
# 1        13:15:00
# 2        04:25:00
# 3        23:30:00
# 4        21:35:00
#            ...
# 10678    22:25:00
# 10679    23:20:00
# 10680    11:20:00
# 10681    14:10:00
# 10682    19:15:00
# Name: Arrival_Time, Length: 10683, dtype: object

# %% [markdown]
# #### 19.Extract the arrival hour and minute into Arrival_Hour and Arrival_Minute.

# %%
df['Arrival_Time'] = pd.to_datetime(df['Arrival_Time'])
df['Arrival_Hour'] = df['Arrival_Time'].dt.hour
df['Arrival_Minute'] = df['Arrival_Time'].dt.minute
df['Arrival_Minute']
# Out:
# C:\Users\Soham\AppData\Local\Temp\ipykernel_21528\780287868.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Arrival_Time'] = pd.to_datetime(df['Arrival_Time'])
# 0        10
# 1        15
# 2        25
# 3        30
# 4        35
#          ..
# 10678    25
# 10679    20
# 10680    20
# 10681    10
# 10682    15
# Name: Arrival_Minute, Length: 10683, dtype: int32

# %% [markdown]
# #### 20.Drop the original Arrival_Time column after extracting the required features.

# %%
df.drop('Arrival_Time',axis=1)
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Duration Total_Stops Additional_Info  \
# 0                  BLR → DEL    22:20   2h 50m    non-stop         No info
# 1      CCU → IXR → BBI → BLR    05:50   7h 25m     2 stops         No info
# 2      DEL → LKO → BOM → COK    09:25      19h     2 stops         No info
# 3            CCU → NAG → BLR    18:05   5h 25m      1 stop         No info
# 4            BLR → NAG → DEL    16:50   4h 45m      1 stop         No info
# ...                      ...      ...      ...         ...             ...
# 10678              CCU → BLR    19:55   2h 30m    non-stop         No info
# 10679              CCU → BLR    20:45   2h 35m    non-stop         No info
# 10680              BLR → DEL    08:20       3h    non-stop         No info
# 10681              BLR → DEL    11:30   2h 40m    non-stop         No info
# 10682  DEL → GOI → BOM → COK    10:55   8h 20m     2 stops         No info
#
#        Price      time  Arrival_Hour  Arrival_Minute
# 0       3897  01:10:00             1              10
# 1       7662  13:15:00            13              15
# 2      13882  04:25:00             4              25
# 3       6218  23:30:00            23              30
# 4      13302  21:35:00            21              35
# ...      ...       ...           ...             ...
# 10678   4107  22:25:00            22              25
# 10679   4145  23:20:00            23              20
# 10680   7229  11:20:00            11              20
# 10681  12648  14:10:00            14              10
# 10682  11753  19:15:00            19              15
#
# [10683 rows x 13 columns]

# %% [markdown]
# #### 21.Extract the hour component from Duration and create Duration_Hour. Handle invalid or missing extracted values appropriately.

# %%
df['Duration_Hour'] = df['Duration'].str.extract(r'(\d+)h')
df['Duration_Hour'] = pd.to_numeric(df['Duration_Hour'], errors='coerce')
df['Duration_Hour'] = df['Duration_Hour'].fillna(0).astype(int)

df['Duration_Hour']
# Out:
# 0         2
# 1         7
# 2        19
# 3         5
# 4         4
#          ..
# 10678     2
# 10679     2
# 10680     3
# 10681     2
# 10682     8
# Name: Duration_Hour, Length: 10683, dtype: int32

# %% [markdown]
# #### 22.Extract the minute component from Duration and create Duration_Minute. Handle invalid or missing extracted values appropriately.

# %%
df.

# %% [markdown]
# #### 23.Drop the original Duration column after creating the numerical duration features.

# %% [markdown]
# #### 24.Replace non-stop in Total_Stops with 0 stops.

# %% [markdown]
# #### 25.Extract only the numerical value from Total_Stops and convert the column into an integer data type. Handle missing or invalid values appropriately.

# %% [markdown]
# #### 26.Split the Route column using → as the separator and create Route_1, Route_2, Route_3, Route_4, and Route_5.

# %% [markdown]
# #### 27.Identify the missing values created in Route_3, Route_4, and Route_5 after splitting the route.

# %% [markdown]
# #### 28.Replace the missing values in the route columns with an appropriate value such as None.

# %% [markdown]
# #### 29.Drop the original Route column after creating and cleaning the route features.

# %% [markdown]
# #### 30.After completing all data cleaning and feature engineering, separate the dataset into X (independent variables) and y (target variable), where Price is the target.
